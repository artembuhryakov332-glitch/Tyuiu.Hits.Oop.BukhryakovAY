// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания № 4

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// ### Описание задачи:
// Создать базовый класс Product в C#, который будет представлять информацию о
// продуктах. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.
// Требования к базовому классу Product:
// • Атрибуты: Название (Name), Цена (Price), Производитель (Manufacturer).
// • Методы:
// o GetInfo(): метод для получения информации о продукте в виде строки.
// o Discount(): метод для применения скидки к цене продукта.
// o Display(): метод для отображения информации о продукте на экране.
//
// Требования к производным классам:
// 1. Электроника (Electronics): Должен содержать дополнительные атрибуты,
// такие как Гарантийный срок (WarrantyPeriod). Метод Discount() должен быть
// переопределен для добавления логики учета гарантийного срока при
// применении скидки.
// 2. Одежда (Clothing): Должен содержать дополнительные атрибуты, такие как
// Размер (Size). Метод Display() должен быть переопределен для добавления
// информации о размере при отображении информации о продукте.
// 3. Книги (Books) (если требуется третий класс): Должен содержать
// дополнительные атрибуты, такие как Автор (Author). Метод GetInfo() должен
// быть переопределен для включения информации об авторе в описании
// продукта.
//
// #### Дополнительное задание
// Добавьте к сущестующим классам конструктора классов с использованием гетторов и сетторов и реализуйте взаимодействие объектов между собой

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;
public abstract class Product 
{
    private string _name;
    private decimal _price;
    private string _manufacturer;

    public string Name
    {
        get{return _name;}
        set{
            if (!string.IsNullOrWhiteSpace(value) && value.Length > 1)
                _name = value;
            else
                throw new ArgumentException("Неверное значение имени");
        }
    }

    public decimal Price
    {
        get{return _price;}
        set{
            if (value >= 0)
                _price = value;
            else
                throw new ArgumentException("Неверное значение цены");
        }
    }

    public string Manufacturer
    {
        get{return _manufacturer;}
        set{
            if (!string.IsNullOrWhiteSpace(value) && value.Length > 1)
                _manufacturer = value;
            else
                throw new ArgumentException("Неверное значение производетеля");
        }
    }

    public Product(string nameValue, decimal priceValue, string manufacturerValue)
    {
        Name = nameValue;
        Price = priceValue;
        Manufacturer = manufacturerValue;
    }



    public virtual string GetInfo()
    {
        string info = $"Название товара: {Name}, цена: {Price}, производитель: {Manufacturer}";
        return info;

    }

    public virtual decimal Discount(decimal percent)
    {
        Price = Price - Price*(percent/100);
        return Price;
    }

    public virtual void Display()
    {
        Console.WriteLine(GetInfo());
    }

    public void ComparePriceWith(Product product)
    {
        if (Price > product.Price)
            Console.WriteLine($"Цена на {Name} больше цены на {product.Name}");
        else
            Console.WriteLine($"Цена на {Name} меньше цены на {product.Name}");
    }
}

public class Electronics:Product
{
    private int _warrantyPeriod;

    public int WarrantyPeriod
    {
        get{return _warrantyPeriod;}      
        set{
            if (value >= 0)
                 _warrantyPeriod = value;
            else
                throw new ArgumentException("Гарантия должны быть больше 0");
        }
    }

    public Electronics(string nameValue, decimal priceValue, string manufacturerValue,int warrantyValue) : base(nameValue, priceValue, manufacturerValue)
    {
        WarrantyPeriod = warrantyValue;
    }

    public override decimal Discount(decimal percent)
    {
        if (WarrantyPeriod > 24)
        {
            return Price;
        }
        else
        {
            Price = Price - Price*(percent/100);
            return Price;
        }
    }

    public void ExtendWarranty(int Months)
    {
        WarrantyPeriod += Months;
        Console.WriteLine($"Гарантия на {Name} продлена. Новый срок: {WarrantyPeriod} мес.");
    }

}

public class Clothing:Product
{
    private int _size;

    public int Size
    {
        get{return _size;}
        set{
            if (value >= 0)
                 _size = value;
            else
                throw new ArgumentException("Размер должнен быть больше 0");
        }
    }

    public Clothing(string nameValue, decimal priceValue, string manufacturerValue,int valueSize) : base(nameValue, priceValue, manufacturerValue)
    {
        Size = valueSize;
    }

    public override void Display()
    {
        Console.WriteLine($"{GetInfo()}" + $" размер: {Size}");
    }

    public void CheckSize(int sizeToCheck)
    {
        if (sizeToCheck == Size)
        {
            Console.WriteLine("Такой размер есть в наличии");
        }
        else
        {
            Console.WriteLine("Размер отсутствует");
        }
    }
}


Electronics electronic = new Electronics("Клавиатура",3500,"DNS",12);
Clothing cloth = new Clothing("Пальто",7500,"Ostin",52);

electronic.Display();
electronic.Discount(50);
Console.WriteLine(electronic.Price);

cloth.Display();

electronic.ExtendWarranty(20);
Console.WriteLine(electronic.WarrantyPeriod);
electronic.Discount(50);
Console.WriteLine(electronic.Price);

cloth.Display();
cloth.CheckSize(48);

cloth.ComparePriceWith(electronic);
// Out:
// Название товара: Клавиатура, цена: 3500, производитель: DNS
// 1750,0
// Название товара: Пальто, цена: 7500, производитель: Ostin размер: 52
// Гарантия на Клавиатура продлена. Новый срок: 32 мес.
// 32
// 1750,0
// Название товара: Пальто, цена: 7500, производитель: Ostin размер: 52
// Размер отсутствует
// Цена на Пальто больше цены на Клавиатура
